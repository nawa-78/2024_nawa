# %%
import pandas as pd
df = pd.read_excel("kekka_bunseki.xlsx")

# %%
df_kazu = df["応答数"]
df
# Out:
#            対話行為  応答数
# 0     質問(YesNo)   11
# 1     質問(YesNo)   10
# 2            共感    2
# 3            共感   13
# 4            共感   30
# ...         ...  ...
# 1038       自己開示   23
# 1039   質問(What)   10
# 1040  質問(YesNo)   10
# 1041         共感   17
# 1042         共感    1
#
# [1043 rows x 2 columns]

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# サンプルのDataFrameを作成する


sns.boxplot(data = df_kazu)

# グリッドを表示する
plt.grid(True)

# グラフを表示する
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

print(len(df[df['応答数']== 30]))

plt.hist(df['応答数'], bins=6,range=(0, 30), color='skyblue', edgecolor='black')

# グリッドを表示する
plt.grid(True)

# x軸とy軸にラベルを付ける
plt.xlabel('Repetition Count')
plt.ylabel('Frequency')

# タイトルを付ける


plt.savefig('histogram_example.png', dpi=300)

# ヒストグラムを表示する
plt.show()
# Out:
# 200

# %%
unique_values = df['対話行為'].unique()
print(unique_values)
# Out:
# ['質問(YesNo)' '共感' '自己開示' '質問(What)' 'あいづち']

# %%
kyoukan = df[df["対話行為"] == "共感"]
jikokaiji = df[df["対話行為"] == "自己開示"]
ynsitumon = df[df["対話行為"] == "質問(YesNo)"]
whsitumon = df[df["対話行為"] == "質問(What)"]
aiduti = df[df["対話行為"] == "あいづち"]

print(len(kyoukan))
print(len(jikokaiji))
print(len(ynsitumon))
print(len(whsitumon))
print(len(aiduti))
# Out:
# 374
# 173
# 363
# 64
# 69

# %%
import pandas as pd
import matplotlib.pyplot as plt

print(len(kyoukan[kyoukan['応答数']== 30]))

plt.hist(kyoukan["応答数"], bins=6,range=(0, 30), color='skyblue', edgecolor='black')

# グリッドを表示する
plt.grid(True)

# x軸とy軸にラベルを付ける
plt.xlabel('Repetition Count')
plt.ylabel('Frequency')

# タイトルを付ける

plt.savefig('kyoukan.png', dpi=300)

# ヒストグラムを表示する
plt.show()
# Out:
# 128

# %%
import pandas as pd
import matplotlib.pyplot as plt

print(len(jikokaiji[jikokaiji['応答数']== 30]))

plt.hist(jikokaiji["応答数"], bins=6,range=(0, 30), color='skyblue', edgecolor='black')

# グリッドを表示する
plt.grid(True)

# x軸とy軸にラベルを付ける
plt.xlabel('Repetition Count')
plt.ylabel('Frequency')

# タイトルを付ける


plt.savefig('jikokaiji.png', dpi=300)

# ヒストグラムを表示する
plt.show()
# Out:
# 10

# %%
import pandas as pd
import matplotlib.pyplot as plt

print(len(ynsitumon[ynsitumon['応答数']== 30]))
plt.hist(ynsitumon["応答数"], bins=6,range=(0, 30), color='skyblue', edgecolor='black')

# グリッドを表示する
plt.grid(True)

# x軸とy軸にラベルを付ける
plt.xlabel('Repetition Count')
plt.ylabel('Frequency')

# タイトルを付ける


plt.savefig('ynsitumon.png', dpi=300)

# ヒストグラムを表示する
plt.show()
# Out:
# 48

# %%
import pandas as pd
import matplotlib.pyplot as plt
print(len(whsitumon[whsitumon['応答数']== 30]))

plt.hist(whsitumon["応答数"], bins=6,range=(0, 30), color='skyblue', edgecolor='black')

# グリッドを表示する
plt.grid(True)

# x軸とy軸にラベルを付ける
plt.xlabel('Repetition Count')
plt.ylabel('Frequency')

# タイトルを付ける


plt.savefig('yhsitumon_example.png', dpi=300)

# ヒストグラムを表示する
plt.show()
# Out:
# 1

# %%
import pandas as pd
import matplotlib.pyplot as plt

print(len(aiduti[aiduti['応答数']== 30]))

plt.hist(aiduti["応答数"], bins=6,range=(0, 30), color='skyblue', edgecolor='black')

# グリッドを表示する
plt.grid(True)

# x軸とy軸にラベルを付ける
plt.xlabel('Repetition Count')
plt.ylabel('Frequency')

# タイトルを付ける


# plt.savefig('aiduti.png', dpi=300)

# ヒストグラムを表示する
plt.show()
# Out:
# 13
